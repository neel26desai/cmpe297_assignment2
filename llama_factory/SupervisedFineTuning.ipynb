# %% [markdown]
# <a href="https://colab.research.google.com/github/neel26desai/cmpe297_assignment2/blob/main/llama_factory/SupervisedFineTuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/
# %rm -rf LLaMA-Factory
# !git clone --depth 1 https://github.com/hiyouga/LLaMA-Factory.git
# %cd LLaMA-Factory
# %ls
# !pip install torch==2.3.1 torchvision==0.18.1 torchaudio==2.3.1
# !pip uninstall -y jax
# !pip install -e .[torch,bitsandbytes,liger-kernel]

# %%
# !pip install git+https://github.com/huggingface/transformers
# !pip install liger-kernel
# Out:
# Collecting git+https://github.com/huggingface/transformers
#   Cloning https://github.com/huggingface/transformers to /tmp/pip-req-build-3opmr9n9
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers /tmp/pip-req-build-3opmr9n9
#   Resolved https://github.com/huggingface/transformers to commit 8bd2b1e8c23234cd607ca8d63f53c1edfea27462
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.45.0.dev0) (3.16.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers==4.45.0.dev0) (0.24.6)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.45.0.dev0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.45.0.dev0) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.45.0.dev0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.45.0.dev0) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.45.0.dev0) (2.32.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers==4.45.0.dev0) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.45.0.dev0) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.45.0.dev0) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.45.0.dev0) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.45.0.dev0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.45.0.dev0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.45.0.dev0) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.45.0.dev0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.45.0.dev0) (2024.8.30)
# Building wheels for collected packages: transformers
#   Building wheel for transformers (pyproject.toml) ... done
#   Created wheel for transformers: filename=transformers-4.45.0.dev0-py3-none-any.whl size=9732511 sha256=6cbe0ab6ece82b0c5a0994bb9b1ef804cdb91cbb295a16c83498ea260691ae69
#   Stored in directory: /tmp/pip-ephem-wheel-cache-pqxxfftp/wheels/c0/14/d6/6c9a5582d2ac191ec0a483be151a4495fe1eb2a6706ca49f1b
# Successfully built transformers
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.44.2
#     Uninstalling transformers-4.44.2:
#       Successfully uninstalled transformers-4.44.2
# Successfully installed transformers-4.45.0.dev0
# Requirement already satisfied: liger-kernel in /usr/local/lib/python3.10/dist-packages (0.3.0)
# Requirement already satisfied: torch>=2.1.2 in /usr/local/lib/python3.10/dist-packages (from liger-kernel) (2.3.1)
# Requirement already satisfied: triton>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from liger-kernel) (2.3.1)
# Requirement already satisfied: transformers>=4.42.0 in /usr/local/lib/python3.10/dist-packages (from liger-kernel) (4.45.0.dev0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.2->liger-kernel) (3.16.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.2->liger-kernel) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.2->liger-kernel) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.2->liger-kernel) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.2->liger-kernel) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.2->liger-kernel) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.2->liger-kernel) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.2->liger-kernel) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.2->liger-kernel) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.2->liger-kernel) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.2->liger-kernel) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.2->liger-kernel) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.2->liger-kernel) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.2->liger-kernel) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.2->liger-kernel) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.2->liger-kernel) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.2->liger-kernel) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.1.2->liger-kernel) (12.6.68)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.42.0->liger-kernel) (0.24.6)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.42.0->liger-kernel) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.42.0->liger-kernel) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.42.0->liger-kernel) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.42.0->liger-kernel) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers>=4.42.0->liger-kernel) (2.32.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.42.0->liger-kernel) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.42.0->liger-kernel) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.42.0->liger-kernel) (4.66.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.1.2->liger-kernel) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.42.0->liger-kernel) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.42.0->liger-kernel) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.42.0->liger-kernel) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.42.0->liger-kernel) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=2.1.2->liger-kernel) (1.3.0)

# %%
import torch
try:
  assert torch.cuda.is_available() is True
except AssertionError:
  print("Please set up a GPU before using LLaMA Factory: https://medium.com/mlearning-ai/training-yolov4-on-google-colab-316f8fff99c6")

# %%
import json

# %cd /content/LLaMA-Factory/

NAME = "Llama-3"
AUTHOR = "LLaMA Factory"

with open("data/identity.json", "r", encoding="utf-8") as f:
  dataset = json.load(f)

for sample in dataset:
  sample["output"] = sample["output"].replace("{{"+ "name" + "}}", NAME).replace("{{"+ "author" + "}}", AUTHOR)

with open("data/identity.json", "w", encoding="utf-8") as f:
  json.dump(dataset, f, indent=2, ensure_ascii=False)
# Out:
# /content/LLaMA-Factory

# %%
import os

# %%
from google.colab import userdata
HF_TOKEN2 = userdata.get('HF_TOKEN2')

# %%
# !huggingface-cli login --token $HF_TOKEN2 --add-to-git-credential
# Out:
# Token is valid (permission: write).
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# Token has not been saved to git credential helper.
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %% [markdown]
# ## Supervised Finetunning

# %%
import json

args = dict(
  stage="sft",                        # do supervised fine-tuning
  do_train=True,
  model_name_or_path="unsloth/llama-3-8b-Instruct-bnb-4bit", # use bnb-4bit-quantized Llama-3-8B-Instruct model
  dataset="identity,alpaca_en_demo",             # use alpaca and identity datasets
  template="llama3",                     # use llama3 prompt template
  finetuning_type="lora",                   # use LoRA adapters to save memory
  lora_target="all",                     # attach LoRA adapters to all linear layers
  output_dir="llama3_lora",                  # the path to save LoRA adapters
  per_device_train_batch_size=2,               # the batch size
  gradient_accumulation_steps=4,               # the gradient accumulation steps
  lr_scheduler_type="cosine",                 # use cosine learning rate scheduler
  logging_steps=10,                      # log every 10 steps
  warmup_ratio=0.1,                      # use warmup scheduler
  save_steps=1000,                      # save checkpoint every 1000 steps
  learning_rate=5e-5,                     # the learning rate
  num_train_epochs=3.0,                    # the epochs of training
  max_samples=500,                      # use 500 examples in each dataset
  max_grad_norm=1.0,                     # clip gradient norm to 1.0
  loraplus_lr_ratio=16.0,                   # use LoRA+ algorithm with lambda=16.0
  fp16=True,                         # use float16 mixed precision training
  use_liger_kernel=True,                   # use liger kernel for efficient training
)

json.dump(args, open("train_llama3.json", "w", encoding="utf-8"), indent=2)

# %%
# %cd /content/LLaMA-Factory/

# !llamafactory-cli train train_llama3.json
# Out:
# /content/LLaMA-Factory
# 2024-09-15 18:05:16.392364: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-15 18:05:16.412434: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-15 18:05:16.418480: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-15 18:05:16.433069: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-15 18:05:17.542389: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 09/15/2024 18:05:23 - INFO - llamafactory.hparams.parser - Process rank: 0, device: cuda:0, n_gpu: 1, distributed training: False, compute dtype: torch.float16
# config.json: 100% 1.26k/1.26k [00:00<00:00, 9.13MB/s]
# [INFO|configuration_utils.py:672] 2024-09-15 18:05:23,590 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/f296897830363557c84cc4a942c2cd1f91818ae4/config.json
# [INFO|configuration_utils.py:739] 2024-09-15 18:05:23,591 >> Model config LlamaConfig {
#   "_name_or_path": "unsloth/llama-3-8b-Instruct-bnb-4bit",
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 128000,
#   "eos_token_id": 128009,
#   "head_dim": 128,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 8192,
#   "mlp_bias": false,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "pad_token_id": 128255,
#   "pretraining_tp": 1,
#   "quantization_config": {
#     "_load_in_4bit": true,
#     "_load_in_8bit": false,
#     "bnb_4bit_compute_dtype": "bfloat16",
#     "bnb_4bit_quant_storage": "uint8",
#     "bnb_4bit_quant_type": "nf4",
#     "bnb_4bit_use_double_quant": true,
#     "llm_int8_enable_fp32_cpu_offload": false,
#     "llm_int8_has_fp16_weight": false,
#     "llm_int8_skip_modules": null,
#     "llm_int8_threshold": 6.0,
#     "load_in_4bit": true,
#     "load_in_8bit": false,
#     "quant_method": "bitsandbytes"
#   },
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": null,
#   "rope_theta": 500000.0,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.45.0.dev0",
#   "unsloth_version": "2024.9",
#   "use_cache": true,
#   "vocab_size": 128256
# }
#
# tokenizer_config.json: 100% 51.1k/51.1k [00:00<00:00, 6.24MB/s]
# tokenizer.json: 100% 9.09M/9.09M [00:00<00:00, 33.1MB/s]
# special_tokens_map.json: 100% 345/345 [00:00<00:00, 2.56MB/s]
# [INFO|tokenization_utils_base.py:2215] 2024-09-15 18:05:24,710 >> loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/f296897830363557c84cc4a942c2cd1f91818ae4/tokenizer.json
# [INFO|tokenization_utils_base.py:2215] 2024-09-15 18:05:24,710 >> loading file tokenizer.model from cache at None
# [INFO|tokenization_utils_base.py:2215] 2024-09-15 18:05:24,710 >> loading file added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:2215] 2024-09-15 18:05:24,710 >> loading file special_tokens_map.json from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/f296897830363557c84cc4a942c2cd1f91818ae4/special_tokens_map.json
# [INFO|tokenization_utils_base.py:2215] 2024-09-15 18:05:24,710 >> loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/f296897830363557c84cc4a942c2cd1f91818ae4/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2479] 2024-09-15 18:05:25,139 >> Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# [INFO|configuration_utils.py:672] 2024-09-15 18:05:25,529 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/f296897830363557c84cc4a942c2cd1f91818ae4/config.json
# [INFO|configuration_utils.py:739] 2024-09-15 18:05:25,530 >> Model config LlamaConfig {
#   "_name_or_path": "unsloth/llama-3-8b-Instruct-bnb-4bit",
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 128000,
#   "eos_token_id": 128009,
#   "head_dim": 128,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 8192,
#   "mlp_bias": false,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "pad_token_id": 128255,
#   "pretraining_tp": 1,
#   "quantization_config": {
#     "_load_in_4bit": true,
#     "_load_in_8bit": false,
#     "bnb_4bit_compute_dtype": "bfloat16",
#     "bnb_4bit_quant_storage": "uint8",
#     "bnb_4bit_quant_type": "nf4",
#     "bnb_4bit_use_double_quant": true,
#     "llm_int8_enable_fp32_cpu_offload": false,
#     "llm_int8_has_fp16_weight": false,
#     "llm_int8_skip_modules": null,
#     "llm_int8_threshold": 6.0,
#     "load_in_4bit": true,
#     "load_in_8bit": false,
#     "quant_method": "bitsandbytes"
#   },
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": null,
#   "rope_theta": 500000.0,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.45.0.dev0",
#   "unsloth_version": "2024.9",
#   "use_cache": true,
#   "vocab_size": 128256
# }
#
# [INFO|tokenization_utils_base.py:2215] 2024-09-15 18:05:25,624 >> loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/f296897830363557c84cc4a942c2cd1f91818ae4/tokenizer.json
# [INFO|tokenization_utils_base.py:2215] 2024-09-15 18:05:25,624 >> loading file tokenizer.model from cache at None
# [INFO|tokenization_utils_base.py:2215] 2024-09-15 18:05:25,624 >> loading file added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:2215] 2024-09-15 18:05:25,624 >> loading file special_tokens_map.json from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/f296897830363557c84cc4a942c2cd1f91818ae4/special_tokens_map.json
# [INFO|tokenization_utils_base.py:2215] 2024-09-15 18:05:25,624 >> loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/f296897830363557c84cc4a942c2cd1f91818ae4/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2479] 2024-09-15 18:05:26,096 >> Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 09/15/2024 18:05:26 - INFO - llamafactory.data.template - Replace eos token: <|eot_id|>
# 09/15/2024 18:05:26 - INFO - llamafactory.data.loader - Loading dataset identity.json...
# Generating train split: 91 examples [00:00, 1950.44 examples/s]
# Converting format of dataset: 100% 91/91 [00:00<00:00, 7510.46 examples/s]
# 09/15/2024 18:05:26 - INFO - llamafactory.data.loader - Loading dataset alpaca_en_demo.json...
# Generating train split: 1000 examples [00:00, 41990.91 examples/s]
# Converting format of dataset: 100% 500/500 [00:00<00:00, 1084.69 examples/s]
# Running tokenizer on dataset: 100% 591/591 [00:00<00:00, 1224.62 examples/s]
# training example:
# input_ids:
# [128000, 128006, 882, 128007, 271, 6151, 128009, 128006, 78191, 128007, 271, 9906, 0, 358, 1097, 445, 81101, 12, 18, 11, 459, 15592, 18328, 8040, 555, 445, 8921, 4940, 17367, 13, 2650, 649, 358, 7945, 499, 3432, 30, 128009]
# inputs:
# <|begin_of_text|><|start_header_id|>user<|end_header_id|>
#
# hi<|eot_id|><|start_header_id|>assistant<|end_header_id|>
#
# Hello! I am Llama-3, an AI assistant developed by LLaMA Factory. How can I assist you today?<|eot_id|>
# label_ids:
# [-100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, 9906, 0, 358, 1097, 445, 81101, 12, 18, 11, 459, 15592, 18328, 8040, 555, 445, 8921, 4940, 17367, 13, 2650, 649, 358, 7945, 499, 3432, 30, 128009]
# labels:
# Hello! I am Llama-3, an AI assistant developed by LLaMA Factory. How can I assist you today?<|eot_id|>
# [INFO|configuration_utils.py:672] 2024-09-15 18:05:27,917 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/f296897830363557c84cc4a942c2cd1f91818ae4/config.json
# [INFO|configuration_utils.py:739] 2024-09-15 18:05:27,918 >> Model config LlamaConfig {
#   "_name_or_path": "unsloth/llama-3-8b-Instruct-bnb-4bit",
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 128000,
#   "eos_token_id": 128009,
#   "head_dim": 128,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 8192,
#   "mlp_bias": false,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "pad_token_id": 128255,
#   "pretraining_tp": 1,
#   "quantization_config": {
#     "_load_in_4bit": true,
#     "_load_in_8bit": false,
#     "bnb_4bit_compute_dtype": "bfloat16",
#     "bnb_4bit_quant_storage": "uint8",
#     "bnb_4bit_quant_type": "nf4",
#     "bnb_4bit_use_double_quant": true,
#     "llm_int8_enable_fp32_cpu_offload": false,
#     "llm_int8_has_fp16_weight": false,
#     "llm_int8_skip_modules": null,
#     "llm_int8_threshold": 6.0,
#     "load_in_4bit": true,
#     "load_in_8bit": false,
#     "quant_method": "bitsandbytes"
#   },
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": null,
#   "rope_theta": 500000.0,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.45.0.dev0",
#   "unsloth_version": "2024.9",
#   "use_cache": true,
#   "vocab_size": 128256
# }
#
# 09/15/2024 18:05:27 - INFO - llamafactory.model.model_utils.quantization - Loading ?-bit BITSANDBYTES-quantized model.
# [WARNING|quantization_config.py:399] 2024-09-15 18:05:28,128 >> Unused kwargs: ['_load_in_4bit', '_load_in_8bit', 'quant_method']. These kwargs are not used in <class 'transformers.utils.quantization_config.BitsAndBytesConfig'>.
# model.safetensors: 100% 5.70G/5.70G [00:58<00:00, 98.1MB/s]
# [INFO|modeling_utils.py:3694] 2024-09-15 18:06:26,544 >> loading weights file model.safetensors from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/f296897830363557c84cc4a942c2cd1f91818ae4/model.safetensors
# [INFO|modeling_utils.py:1613] 2024-09-15 18:06:26,721 >> Instantiating LlamaForCausalLM model under default dtype torch.float16.
# [INFO|configuration_utils.py:1097] 2024-09-15 18:06:26,725 >> Generate config GenerationConfig {
#   "bos_token_id": 128000,
#   "eos_token_id": 128009,
#   "pad_token_id": 128255
# }
#
# [INFO|modeling_utils.py:4526] 2024-09-15 18:06:51,268 >> All model checkpoint weights were used when initializing LlamaForCausalLM.
#
# [INFO|modeling_utils.py:4534] 2024-09-15 18:06:51,268 >> All the weights of LlamaForCausalLM were initialized from the model checkpoint at unsloth/llama-3-8b-Instruct-bnb-4bit.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use LlamaForCausalLM for predictions without further training.
# generation_config.json: 100% 220/220 [00:00<00:00, 1.29MB/s]
# [INFO|configuration_utils.py:1052] 2024-09-15 18:06:51,478 >> loading configuration file generation_config.json from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/f296897830363557c84cc4a942c2cd1f91818ae4/generation_config.json
# [INFO|configuration_utils.py:1097] 2024-09-15 18:06:51,479 >> Generate config GenerationConfig {
#   "bos_token_id": 128000,
#   "do_sample": true,
#   "eos_token_id": [
#     128001,
#     128009
#   ],
#   "max_length": 8192,
#   "pad_token_id": 128255,
#   "temperature": 0.6,
#   "top_p": 0.9
# }
#
# 09/15/2024 18:06:51 - INFO - llamafactory.model.model_utils.checkpointing - Gradient checkpointing enabled.
# 09/15/2024 18:06:51 - INFO - llamafactory.model.model_utils.attention - Using torch SDPA for faster training and inference.
# 09/15/2024 18:06:51 - INFO - llamafactory.model.adapter - Upcasting trainable params to float32.
# 09/15/2024 18:06:51 - INFO - llamafactory.model.adapter - Fine-tuning method: LoRA
# 09/15/2024 18:06:51 - INFO - llamafactory.model.model_utils.misc - Found linear modules: v_proj,down_proj,q_proj,up_proj,k_proj,gate_proj,o_proj
# 09/15/2024 18:06:52 - INFO - llamafactory.model.loader - trainable params: 20,971,520 || all params: 8,051,232,768 || trainable%: 0.2605
# [INFO|trainer.py:668] 2024-09-15 18:06:52,362 >> Using auto half precision backend
# 09/15/2024 18:06:52 - INFO - llamafactory.train.trainer_utils - Using LoRA+ optimizer with loraplus lr ratio 16.00.
# [INFO|trainer.py:2213] 2024-09-15 18:06:52,774 >> ***** Running training *****
# [INFO|trainer.py:2214] 2024-09-15 18:06:52,774 >>   Num examples = 591
# [INFO|trainer.py:2215] 2024-09-15 18:06:52,774 >>   Num Epochs = 3
# [INFO|trainer.py:2216] 2024-09-15 18:06:52,774 >>   Instantaneous batch size per device = 2
# [INFO|trainer.py:2219] 2024-09-15 18:06:52,774 >>   Total train batch size (w. parallel, distributed & accumulation) = 8
# [INFO|trainer.py:2220] 2024-09-15 18:06:52,774 >>   Gradient Accumulation steps = 4
# [INFO|trainer.py:2221] 2024-09-15 18:06:52,774 >>   Total optimization steps = 222
# [INFO|trainer.py:2222] 2024-09-15 18:06:52,779 >>   Number of trainable parameters = 20,971,520
# {'loss': 1.3718, 'grad_norm': 0.7038185000419617, 'learning_rate': 2.173913043478261e-05, 'epoch': 0.14}
# {'loss': 1.2243, 'grad_norm': 1.9966844320297241, 'learning_rate': 4.347826086956522e-05, 'epoch': 0.27}
# {'loss': 1.0243, 'grad_norm': 0.7209504246711731, 'learning_rate': 4.98475042744222e-05, 'epoch': 0.41}
# {'loss': 1.0827, 'grad_norm': 1.1190775632858276, 'learning_rate': 4.910506156279029e-05, 'epoch': 0.54}
# {'loss': 1.0133, 'grad_norm': 1.3735984563827515, 'learning_rate': 4.7763104379936555e-05, 'epoch': 0.68}
# {'loss': 1.0055, 'grad_norm': 0.9749905467033386, 'learning_rate': 4.585500840294794e-05, 'epoch': 0.81}
# {'loss': 1.0701, 'grad_norm': 1.1550137996673584, 'learning_rate': 4.342822968779448e-05, 'epoch': 0.95}
# {'loss': 0.8442, 'grad_norm': 2.0353822708129883, 'learning_rate': 4.054312439471239e-05, 'epoch': 1.08}
# {'loss': 0.7175, 'grad_norm': 0.4804060161113739, 'learning_rate': 3.727144767643984e-05, 'epoch': 1.22}
# {'loss': 0.795, 'grad_norm': 1.0269259214401245, 'learning_rate': 3.369456906329956e-05, 'epoch': 1.35}
# {'loss': 0.8143, 'grad_norm': 1.641953468322754, 'learning_rate': 2.990144873009946e-05, 'epoch': 1.49}
# {'loss': 0.7006, 'grad_norm': 0.7923349142074585, 'learning_rate': 2.5986424976906322e-05, 'epoch': 1.62}
# {'loss': 0.6905, 'grad_norm': 1.4804413318634033, 'learning_rate': 2.2046867951027303e-05, 'epoch': 1.76}
# {'loss': 0.7301, 'grad_norm': 0.5607053637504578, 'learning_rate': 1.8180757964234924e-05, 'epoch': 1.89}
# {'loss': 0.6045, 'grad_norm': 0.7934386730194092, 'learning_rate': 1.4484248634655401e-05, 'epoch': 2.03}
# {'loss': 0.5632, 'grad_norm': 1.0239065885543823, 'learning_rate': 1.1049275460163999e-05, 'epoch': 2.16}
# {'loss': 0.5477, 'grad_norm': 0.6966880559921265, 'learning_rate': 7.961269300209159e-06, 'epoch': 2.3}
# {'loss': 0.5527, 'grad_norm': 1.0155718326568604, 'learning_rate': 5.297031633820193e-06, 'epoch': 2.43}
# {'loss': 0.5393, 'grad_norm': 1.2119060754776, 'learning_rate': 3.1228244380351602e-06, 'epoch': 2.57}
# {'loss': 0.4364, 'grad_norm': 0.6431164741516113, 'learning_rate': 1.4927221931831131e-06, 'epoch': 2.7}
# {'loss': 0.4932, 'grad_norm': 0.8762556910514832, 'learning_rate': 4.472670021254899e-07, 'epoch': 2.84}
# {'loss': 0.5192, 'grad_norm': 1.0821679830551147, 'learning_rate': 1.2460271845654569e-08, 'epoch': 2.97}
# 100% 222/222 [34:50<00:00,  8.58s/it][INFO|trainer.py:3675] 2024-09-15 18:41:43,286 >> Saving model checkpoint to llama3_lora/checkpoint-222
# [INFO|configuration_utils.py:672] 2024-09-15 18:41:43,553 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/f296897830363557c84cc4a942c2cd1f91818ae4/config.json
# [INFO|configuration_utils.py:739] 2024-09-15 18:41:43,554 >> Model config LlamaConfig {
#   "_name_or_path": "unsloth/llama-3-8b-Instruct",
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 128000,
#   "eos_token_id": 128009,
#   "head_dim": 128,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 8192,
#   "mlp_bias": false,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "pad_token_id": 128255,
#   "pretraining_tp": 1,
#   "quantization_config": {
#     "_load_in_4bit": true,
#     "_load_in_8bit": false,
#     "bnb_4bit_compute_dtype": "bfloat16",
#     "bnb_4bit_quant_storage": "uint8",
#     "bnb_4bit_quant_type": "nf4",
#     "bnb_4bit_use_double_quant": true,
#     "llm_int8_enable_fp32_cpu_offload": false,
#     "llm_int8_has_fp16_weight": false,
#     "llm_int8_skip_modules": null,
#     "llm_int8_threshold": 6.0,
#     "load_in_4bit": true,
#     "load_in_8bit": false,
#     "quant_method": "bitsandbytes"
#   },
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": null,
#   "rope_theta": 500000.0,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.45.0.dev0",
#   "unsloth_version": "2024.9",
#   "use_cache": true,
#   "vocab_size": 128256
# }
#
# [INFO|tokenization_utils_base.py:2650] 2024-09-15 18:41:43,786 >> tokenizer config file saved in llama3_lora/checkpoint-222/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2659] 2024-09-15 18:41:43,786 >> Special tokens file saved in llama3_lora/checkpoint-222/special_tokens_map.json
# [INFO|trainer.py:2475] 2024-09-15 18:41:46,575 >>
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# {'train_runtime': 2093.7961, 'train_samples_per_second': 0.847, 'train_steps_per_second': 0.106, 'train_loss': 0.7849922335899628, 'epoch': 3.0}
# 100% 222/222 [34:53<00:00,  9.43s/it]
# [INFO|trainer.py:3675] 2024-09-15 18:41:46,578 >> Saving model checkpoint to llama3_lora
# [INFO|configuration_utils.py:672] 2024-09-15 18:41:46,905 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/f296897830363557c84cc4a942c2cd1f91818ae4/config.json
# [INFO|configuration_utils.py:739] 2024-09-15 18:41:46,907 >> Model config LlamaConfig {
#   "_name_or_path": "unsloth/llama-3-8b-Instruct",
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 128000,
#   "eos_token_id": 128009,
#   "head_dim": 128,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 8192,
#   "mlp_bias": false,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "pad_token_id": 128255,
#   "pretraining_tp": 1,
#   "quantization_config": {
#     "_load_in_4bit": true,
#     "_load_in_8bit": false,
#     "bnb_4bit_compute_dtype": "bfloat16",
#     "bnb_4bit_quant_storage": "uint8",
#     "bnb_4bit_quant_type": "nf4",
#     "bnb_4bit_use_double_quant": true,
#     "llm_int8_enable_fp32_cpu_offload": false,
#     "llm_int8_has_fp16_weight": false,
#     "llm_int8_skip_modules": null,
#     "llm_int8_threshold": 6.0,
#     "load_in_4bit": true,
#     "load_in_8bit": false,
#     "quant_method": "bitsandbytes"
#   },
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": null,
#   "rope_theta": 500000.0,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.45.0.dev0",
#   "unsloth_version": "2024.9",
#   "use_cache": true,
#   "vocab_size": 128256
# }
#
# [INFO|tokenization_utils_base.py:2650] 2024-09-15 18:41:47,221 >> tokenizer config file saved in llama3_lora/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2659] 2024-09-15 18:41:47,221 >> Special tokens file saved in llama3_lora/special_tokens_map.json
# ***** train metrics *****
#   epoch                    =        3.0
#   total_flos               = 16222836GF
#   train_loss               =      0.785
#   train_runtime            = 0:34:53.79
#   train_samples_per_second =      0.847
#   train_steps_per_second   =      0.106
# [INFO|modelcard.py:449] 2024-09-15 18:41:47,471 >> Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Causal Language Modeling', 'type': 'text-generation'}}

# %% [markdown]
# ### Infernce using the supervised fine tuned model.

# %%
from llamafactory.chat import ChatModel
from llamafactory.extras.misc import torch_gc

# %cd /content/LLaMA-Factory/

args = dict(
  model_name_or_path="unsloth/llama-3-8b-Instruct-bnb-4bit", # use bnb-4bit-quantized Llama-3-8B-Instruct model
  adapter_name_or_path="llama3_lora",            # load the saved LoRA adapters
  template="llama3",                     # same to the one in training
  finetuning_type="lora",                  # same to the one in training
  quantization_bit=4,                    # load 4-bit quantized model
)
chat_model = ChatModel(args)

messages = []
print("Welcome to the CLI application, use `clear` to remove the history, use `exit` to exit the application.")
while True:
  query = input("\nUser: ")
  if query.strip() == "exit":
    break
  if query.strip() == "clear":
    messages = []
    torch_gc()
    print("History has been removed.")
    continue

  messages.append({"role": "user", "content": query})
  print("Assistant: ", end="", flush=True)

  response = ""
  for new_text in chat_model.stream_chat(messages):
    print(new_text, end="", flush=True)
    response += new_text
  print()
  messages.append({"role": "assistant", "content": response})

torch_gc()
# Out:
# [INFO|configuration_utils.py:672] 2024-09-15 21:17:24,536 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/f296897830363557c84cc4a942c2cd1f91818ae4/config.json
# [INFO|configuration_utils.py:739] 2024-09-15 21:17:24,540 >> Model config LlamaConfig {
#   "_name_or_path": "unsloth/llama-3-8b-Instruct-bnb-4bit",
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 128000,
#   "eos_token_id": 128009,
#   "head_dim": 128,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 8192,
#   "mlp_bias": false,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "pad_token_id": 128255,
#   "pretraining_tp": 1,
#   "quantization_config": {
#     "_load_in_4bit": true,
#     "_load_in_8bit": false,
#     "bnb_4bit_compute_dtype": "bfloat16",
#     "bnb_4bit_quant_storage": "uint8",
#     "bnb_4bit_quant_type": "nf4",
#     "bnb_4bit_use_double_quant": true,
#     "llm_int8_enable_fp32_cpu_offload": false,
#     "llm_int8_has_fp16_weight": false,
#     "llm_int8_skip_modules": null,
#     "llm_int8_threshold": 6.0,
#     "load_in_4bit": true,
#     "load_in_8bit": false,
#     "quant_method": "bitsandbytes"
#   },
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": null,
#   "rope_theta": 500000.0,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.45.0.dev0",
#   "unsloth_version": "2024.9",
#   "use_cache": true,
#   "vocab_size": 128256
# }
# /content/LLaMA-Factory
# [INFO|tokenization_utils_base.py:2215] 2024-09-15 21:17:24,638 >> loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/f296897830363557c84cc4a942c2cd1f91818ae4/tokenizer.json
# [INFO|tokenization_utils_base.py:2215] 2024-09-15 21:17:24,639 >> loading file tokenizer.model from cache at None
# [INFO|tokenization_utils_base.py:2215] 2024-09-15 21:17:24,640 >> loading file added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:2215] 2024-09-15 21:17:24,642 >> loading file special_tokens_map.json from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/f296897830363557c84cc4a942c2cd1f91818ae4/special_tokens_map.json
# [INFO|tokenization_utils_base.py:2215] 2024-09-15 21:17:24,645 >> loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/f296897830363557c84cc4a942c2cd1f91818ae4/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2479] 2024-09-15 21:17:25,075 >> Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# [INFO|configuration_utils.py:672] 2024-09-15 21:17:25,464 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/f296897830363557c84cc4a942c2cd1f91818ae4/config.json
# [INFO|configuration_utils.py:739] 2024-09-15 21:17:25,466 >> Model config LlamaConfig {
#   "_name_or_path": "unsloth/llama-3-8b-Instruct-bnb-4bit",
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 128000,
#   "eos_token_id": 128009,
#   "head_dim": 128,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 8192,
#   "mlp_bias": false,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "pad_token_id": 128255,
#   "pretraining_tp": 1,
#   "quantization_config": {
#     "_load_in_4bit": true,
#     "_load_in_8bit": false,
#     "bnb_4bit_compute_dtype": "bfloat16",
#     "bnb_4bit_quant_storage": "uint8",
#     "bnb_4bit_quant_type": "nf4",
#     "bnb_4bit_use_double_quant": true,
#     "llm_int8_enable_fp32_cpu_offload": false,
#     "llm_int8_has_fp16_weight": false,
#     "llm_int8_skip_modules": null,
#     "llm_int8_threshold": 6.0,
#     "load_in_4bit": true,
#     "load_in_8bit": false,
#     "quant_method": "bitsandbytes"
#   },
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": null,
#   "rope_theta": 500000.0,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.45.0.dev0",
#   "unsloth_version": "2024.9",
#   "use_cache": true,
#   "vocab_size": 128256
# }
#
# [INFO|tokenization_utils_base.py:2215] 2024-09-15 21:17:25,563 >> loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/f296897830363557c84cc4a942c2cd1f91818ae4/tokenizer.json
# [INFO|tokenization_utils_base.py:2215] 2024-09-15 21:17:25,564 >> loading file tokenizer.model from cache at None
# [INFO|tokenization_utils_base.py:2215] 2024-09-15 21:17:25,566 >> loading file added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:2215] 2024-09-15 21:17:25,567 >> loading file special_tokens_map.json from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/f296897830363557c84cc4a942c2cd1f91818ae4/special_tokens_map.json
# [INFO|tokenization_utils_base.py:2215] 2024-09-15 21:17:25,568 >> loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/f296897830363557c84cc4a942c2cd1f91818ae4/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2479] 2024-09-15 21:17:26,009 >> Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 09/15/2024 21:17:26 - INFO - llamafactory.data.template - Replace eos token: <|eot_id|>
# [INFO|configuration_utils.py:672] 2024-09-15 21:17:26,259 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/f296897830363557c84cc4a942c2cd1f91818ae4/config.json
# [INFO|configuration_utils.py:739] 2024-09-15 21:17:26,262 >> Model config LlamaConfig {
#   "_name_or_path": "unsloth/llama-3-8b-Instruct-bnb-4bit",
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 128000,
#   "eos_token_id": 128009,
#   "head_dim": 128,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 8192,
#   "mlp_bias": false,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "pad_token_id": 128255,
#   "pretraining_tp": 1,
#   "quantization_config": {
#     "_load_in_4bit": true,
#     "_load_in_8bit": false,
#     "bnb_4bit_compute_dtype": "bfloat16",
#     "bnb_4bit_quant_storage": "uint8",
#     "bnb_4bit_quant_type": "nf4",
#     "bnb_4bit_use_double_quant": true,
#     "llm_int8_enable_fp32_cpu_offload": false,
#     "llm_int8_has_fp16_weight": false,
#     "llm_int8_skip_modules": null,
#     "llm_int8_threshold": 6.0,
#     "load_in_4bit": true,
#     "load_in_8bit": false,
#     "quant_method": "bitsandbytes"
#   },
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": null,
#   "rope_theta": 500000.0,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.45.0.dev0",
#   "unsloth_version": "2024.9",
#   "use_cache": true,
#   "vocab_size": 128256
# }
# 09/15/2024 21:17:26 - WARNING - llamafactory.model.model_utils.quantization - `quantization_bit` will not affect on the PTQ-quantized models.
# 09/15/2024 21:17:26 - INFO - llamafactory.model.model_utils.quantization - Loading ?-bit BITSANDBYTES-quantized model.
# 09/15/2024 21:17:26 - INFO - llamafactory.model.patcher - Using KV cache for faster generation.
# [WARNING|quantization_config.py:399] 2024-09-15 21:17:26,274 >> Unused kwargs: ['_load_in_4bit', '_load_in_8bit', 'quant_method']. These kwargs are not used in <class 'transformers.utils.quantization_config.BitsAndBytesConfig'>.
# [INFO|modeling_utils.py:3694] 2024-09-15 21:17:26,288 >> loading weights file model.safetensors from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/f296897830363557c84cc4a942c2cd1f91818ae4/model.safetensors
# [INFO|modeling_utils.py:1613] 2024-09-15 21:17:26,342 >> Instantiating LlamaForCausalLM model under default dtype torch.bfloat16.
# [INFO|configuration_utils.py:1097] 2024-09-15 21:17:26,352 >> Generate config GenerationConfig {
#   "bos_token_id": 128000,
#   "eos_token_id": 128009,
#   "pad_token_id": 128255
# }
#
# [INFO|quantizer_bnb_4bit.py:115] 2024-09-15 21:17:26,583 >> target_dtype {target_dtype} is replaced by `CustomDtype.INT4` for 4-bit BnB quantization
# [INFO|modeling_utils.py:4526] 2024-09-15 21:17:30,575 >> All model checkpoint weights were used when initializing LlamaForCausalLM.
#
# [INFO|modeling_utils.py:4534] 2024-09-15 21:17:30,577 >> All the weights of LlamaForCausalLM were initialized from the model checkpoint at unsloth/llama-3-8b-Instruct-bnb-4bit.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use LlamaForCausalLM for predictions without further training.
# [INFO|configuration_utils.py:1052] 2024-09-15 21:17:30,678 >> loading configuration file generation_config.json from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/f296897830363557c84cc4a942c2cd1f91818ae4/generation_config.json
# [INFO|configuration_utils.py:1097] 2024-09-15 21:17:30,680 >> Generate config GenerationConfig {
#   "bos_token_id": 128000,
#   "do_sample": true,
#   "eos_token_id": [
#     128001,
#     128009
#   ],
#   "max_length": 8192,
#   "pad_token_id": 128255,
#   "temperature": 0.6,
#   "top_p": 0.9
# }
# 09/15/2024 21:17:30 - INFO - llamafactory.model.model_utils.attention - Using torch SDPA for faster training and inference.
# 09/15/2024 21:17:31 - INFO - llamafactory.model.adapter - Loaded adapter(s): llama3_lora
# 09/15/2024 21:17:31 - INFO - llamafactory.model.loader - all params: 8,051,232,768
# Welcome to the CLI application, use `clear` to remove the history, use `exit` to exit the application.
#
# User: Hello
# Assistant: Hello! I am Llama-3, an AI assistant developed by LLaMA Factory. How can I assist you today?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-02babdfbf1d2> in <cell line: 17>()
#      16 print("Welcome to the CLI application, use `clear` to remove the history, use `exit` to exit the application.")
#      17 while True:
# ---> 18   query = input("\nUser: ")
#      19   if query.strip() == "exit":
#      20     break
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
