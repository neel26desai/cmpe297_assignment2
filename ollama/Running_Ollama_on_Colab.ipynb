# %% [markdown]
# <a href="https://colab.research.google.com/github/neel26desai/cmpe297_assignment2/blob/main/ollama/Running_Ollama_on_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install colab-xterm #https://pypi.org/project/colab-xterm/
# %load_ext colabxterm
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.6/115.6 kB 4.4 MB/s eta 0:00:00
# ...

# %%
# %xterm
# Out:
# Launching Xterm...

# %%
# !ollama list
# Out:
# NAME        	ID          	SIZE  	MODIFIED
# llava:latest	8dd30f6b0cb1	4.7 GB	10 minutes ago

# %%
# !pip install langchain-community
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 47.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 35.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 405.1/405.1 kB 19.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.8/289.8 kB 21.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 11.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
# ...

# %%
# Import Ollama module from Langchain
from langchain_community.llms import Ollama

# Initialize an instance of the Ollama model
llm = Ollama(model="llava")

# Invoke the model to generate responses
response = llm.invoke("Tell me a joke")
print(response)
# Out:
#  Why was the math book sad? Because it had too many problems!

# %%
from IPython.display import display, Image
display(Image(filename='/content/Outside_SJSU.jpg'))

# %%
# Invoke the model to generate responses
response = llm.invoke("Can you describe what is there in the image /content/Outside_SJSU.jpg")
print(response)
# Out:
#  The image shows an outdoor scene at San Jose State University (SJSU). It appears to be taken from a perspective looking out over the campus towards downtown San Jose, with buildings and trees visible in the background. There are also some people present in the foreground, although their activities or identities are not clear due to the distance and angle of the photo.
